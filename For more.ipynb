# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pandas_datareader as web

# %%
tickers = ["FB", "AMZN", "AAPL", "NFLX", "GOOG"]
multpl_stocks = web.get_data_yahoo(tickers,
start = "2020-01-01",
end = "2020-12-31")

# %%
fig = plt.figure()
ax1 = fig.add_subplot(321)
ax2 = fig.add_subplot(322)
ax3 = fig.add_subplot(323)
ax4 = fig.add_subplot(324)
ax5 = fig.add_subplot(325)
ax1.plot(multpl_stocks['Adj Close']['AMZN'])
ax1.set_title("Amazon")
ax2.plot(multpl_stocks['Adj Close']['AAPL'])
ax2.set_title("Apple")
ax3.plot(multpl_stocks['Adj Close']['FB'])
ax3.set_title("Facebook")
ax4.plot(multpl_stocks['Adj Close']['NFLX'])
ax4.set_title("Netflix")
ax5.plot(multpl_stocks['Adj Close']['GOOG'])
ax5.set_title("Google")
plt.tight_layout()
plt.show()

# %%
multpl_stock_daily_returns = multpl_stocks['Adj Close'].pct_change()
multpl_stock_monthly_returns = multpl_stocks['Adj Close'].resample('M').ffill().pct_change()

# %%
fig = plt.figure()
(multpl_stock_monthly_returns + 1).cumprod().plot()
plt.show()

# %%
print(multpl_stock_monthly_returns.mean())
# Out:
# Symbols
# FB      0.029083
# AMZN    0.052608
# AAPL    0.057219
# NFLX    0.045167
# GOOG    0.026490
# dtype: float64

# %%
print(multpl_stock_monthly_returns.std())
# Out:
# Symbols
# FB      0.106225
# AMZN    0.100078
# AAPL    0.114925
# NFLX    0.056727
# GOOG    0.089865
# dtype: float64

# %%
print(multpl_stock_monthly_returns.corr())
# Out:
# Symbols        FB      AMZN      AAPL      NFLX      GOOG
# Symbols
# FB       1.000000  0.700023  0.790205  0.494676  0.855899
# AMZN     0.700023  1.000000  0.754313  0.729447  0.557146
# AAPL     0.790205  0.754313  1.000000  0.665744  0.641009
# NFLX     0.494676  0.729447  0.665744  1.000000  0.293851
# GOOG     0.855899  0.557146  0.641009  0.293851  1.000000

# %%
print(multpl_stock_monthly_returns.cov())
# Out:
# Symbols        FB      AMZN      AAPL      NFLX      GOOG
# Symbols
# FB       0.011284  0.007442  0.009647  0.002981  0.008170
# AMZN     0.007442  0.010016  0.008676  0.004141  0.005011
# AAPL     0.009647  0.008676  0.013208  0.004340  0.006620
# NFLX     0.002981  0.004141  0.004340  0.003218  0.001498
# GOOG     0.008170  0.005011  0.006620  0.001498  0.008076
